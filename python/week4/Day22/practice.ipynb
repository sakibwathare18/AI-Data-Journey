# %%
import numpy as np

# %%
marks = np.array([
    [85, 90, 78],
    [72, 88, 91],
    [90, 95, 89],
    [65, 70, 68]
])

# %%
print(marks.shape)
# Out:
# (4, 3)

# %%
print(marks.ndim)
# Out:
# 2

# %%
print(marks.size)
# Out:
# 12

# %%
print(marks[0])
# Out:
# [85 90 78]

# %%
print(marks[:,1])
# Out:
# [90 88 95 70]

# %%
print(marks[:,2])
# Out:
# [78 91 89 68]

# %%
temperatures = np.array([
    32, 35, 31, 29, 40,
    38, 36, 33, 30, 41
])

# %%
add = temperatures + 2
print(add)
# Out:
# [34 37 33 31 42 40 38 35 32 43]

# %%
sub = temperatures - 5
print(sub)
# Out:
# [27 30 26 24 35 33 31 28 25 36]

# %%
multi = temperatures * 1.8
print(multi)
# Out:
# [57.6 63.  55.8 52.2 72.  68.4 64.8 59.4 54.  73.8]
